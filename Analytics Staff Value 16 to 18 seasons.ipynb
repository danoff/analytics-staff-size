# %%
# Check the versions of libraries
 
# Python version
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy as np
print('numpy: {}'.format(np.__version__))
# matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas as pd
print('pandas: {}'.format(pd.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))

import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from scipy import stats
from statsmodels.compat import lzip
import statsmodels
import matplotlib.pyplot as plt

# %matplotlib inline
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %matplotlib inline
import seaborn

# Load libraries

from pandas.plotting import scatter_matrix
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# Out:
# Python: 3.6.5 |Anaconda, Inc.| (default, Apr 29 2018, 16:28:17)
# [GCC 7.2.0]
# scipy: 1.1.0
# numpy: 1.14.3
# matplotlib: 2.2.2
# pandas: 0.23.0
# sklearn: 0.19.1

# %%
# read CSV of single game data

data = pd.read_csv('nba analytics staff data sixteen to eighteen.csv', header=0)
data = data.dropna()
data.head
# Out:
# <bound method NDFrame.head of             Team          Season                  TeamSeason  Staff  Wins  \
# 0          Hawks   sixteenSeason          HawkssixteenSeason      0    48
# 1        Celtics   sixteenSeason        CelticssixteenSeason      4    48
# 2           Nets   sixteenSeason           NetssixteenSeason      1    21
# 3        Bobcats   sixteenSeason        BobcatssixteenSeason      0    48
# 4          Bulls   sixteenSeason          BullssixteenSeason      2    42
# 5      Cavaliers   sixteenSeason      CavalierssixteenSeason      1    57
# 6      Mavericks   sixteenSeason      MaverickssixteenSeason      1    42
# 7        Nuggets   sixteenSeason        NuggetssixteenSeason      1    33
# 8        Pistons   sixteenSeason        PistonssixteenSeason      2    44
# 9       Warriors   sixteenSeason       WarriorssixteenSeason      2    73
# 10       Rockets   sixteenSeason        RocketssixteenSeason      4    41
# 11        Pacers   sixteenSeason         PacerssixteenSeason      1    45
# 12      Clippers   sixteenSeason       ClipperssixteenSeason      0    53
# 13        Lakers   sixteenSeason         LakerssixteenSeason      2    17
# 14     Grizzlies   sixteenSeason      GrizzliessixteenSeason      1    42
# 15          Heat   sixteenSeason           HeatsixteenSeason      1    48
# 16         Bucks   sixteenSeason          BuckssixteenSeason      1    33
# 17  Timberwolves   sixteenSeason   TimberwolvessixteenSeason      1    29
# 18      Pelicans   sixteenSeason       PelicanssixteenSeason      0    30
# 19        Knicks   sixteenSeason         KnickssixteenSeason      1    32
# 20          City   sixteenSeason           CitysixteenSeason      2    55
# 21         Magic   sixteenSeason          MagicsixteenSeason      0    35
# 22         76ers   sixteenSeason          76erssixteenSeason      2    10
# 23          Suns   sixteenSeason           SunssixteenSeason      3    23
# 24       Blazers   sixteenSeason        BlazerssixteenSeason      2    44
# 25         Kings   sixteenSeason          KingssixteenSeason      1    33
# 26         Spurs   sixteenSeason          SpurssixteenSeason      1    67
# 27       Raptors   sixteenSeason        RaptorssixteenSeason      2    56
# 28          Jazz   sixteenSeason           JazzsixteenSeason      0    40
# 29       Wizards   sixteenSeason        WizardssixteenSeason      3    41
# ..           ...             ...                         ...    ...   ...
# 60         Hawks  eighteenSeason         HawkseighteenSeason      1    24
# 61       Celtics  eighteenSeason       CelticseighteenSeason      4    55
# 62          Nets  eighteenSeason          NetseighteenSeason      3    28
# 63       Bobcats  eighteenSeason       BobcatseighteenSeason      2    36
# 64         Bulls  eighteenSeason         BullseighteenSeason      2    27
# 65     Cavaliers  eighteenSeason     CavalierseighteenSeason      2    50
# 66     Mavericks  eighteenSeason     MaverickseighteenSeason      3    24
# 67       Nuggets  eighteenSeason       NuggetseighteenSeason      2    46
# 68       Pistons  eighteenSeason       PistonseighteenSeason      1    39
# 69      Warriors  eighteenSeason      WarriorseighteenSeason      2    58
# 70       Rockets  eighteenSeason       RocketseighteenSeason      6    65
# 71        Pacers  eighteenSeason        PacerseighteenSeason      2    48
# 72      Clippers  eighteenSeason      ClipperseighteenSeason      1    42
# 73        Lakers  eighteenSeason        LakerseighteenSeason      2    35
# 74     Grizzlies  eighteenSeason     GrizzlieseighteenSeason      2    22
# 75          Heat  eighteenSeason          HeateighteenSeason      2    44
# 76         Bucks  eighteenSeason         BuckseighteenSeason      2    44
# 77  Timberwolves  eighteenSeason  TimberwolveseighteenSeason      3    47
# 78      Pelicans  eighteenSeason      PelicanseighteenSeason      1    48
# 79        Knicks  eighteenSeason        KnickseighteenSeason      2    29
# 80          City  eighteenSeason          CityeighteenSeason      4    48
# 81         Magic  eighteenSeason         MagiceighteenSeason      1    25
# 82         76ers  eighteenSeason         76erseighteenSeason      8    52
# 83          Suns  eighteenSeason          SunseighteenSeason      2    21
# 84       Blazers  eighteenSeason       BlazerseighteenSeason      2    49
# 85         Kings  eighteenSeason         KingseighteenSeason      2    27
# 86         Spurs  eighteenSeason         SpurseighteenSeason      3    47
# 87       Raptors  eighteenSeason       RaptorseighteenSeason      2    59
# 88          Jazz  eighteenSeason          JazzeighteenSeason      1    48
# 89       Wizards  eighteenSeason       WizardseighteenSeason      1    43
#
#      PS/G   PA/G    SRS  Championship  ThreePointers  ThreePointersAttempted  \
# 0   102.8   99.2   3.49             0            9.9                    28.4
# 1   105.7  102.5   2.84             0            8.7                    26.1
# 2    98.6  106.0  -7.12             0            6.5                    18.4
# 3   103.4  100.7   2.36             0           10.6                    29.4
# 4   101.6  103.1  -1.46             0            7.9                    21.4
# 5   104.3   98.3   5.45             1           10.7                    29.6
# 6   102.3  102.6  -0.02             0            9.8                    28.6
# 7   101.9  105.0  -2.81             0            8.0                    23.7
# 8   102.0  101.4   0.43             0            9.0                    26.2
# 9   114.9  104.1  10.38             0           13.1                    31.6
# 10  106.5  106.4   0.34             0           10.7                    30.9
# 11  102.2  100.5   1.62             0            8.1                    23.0
# 12  104.5  100.2   4.13             0            9.7                    26.7
# 13   97.3  106.9  -8.92             0            7.8                    24.6
# 14   99.1  101.3  -2.14             0            6.1                    18.5
# 15  100.0   98.4   1.50             0            6.1                    18.0
# 16   99.0  103.2  -3.98             0            5.4                    15.6
# 17  102.4  106.0  -3.38             0            5.5                    16.4
# 18  102.7  106.5  -3.56             0            8.6                    23.8
# 19   98.4  101.1  -2.74             0            7.4                    21.5
# 20  110.2  102.9   7.09             0            8.3                    23.7
# 21  102.1  103.7  -1.68             0            7.8                    22.2
# 22   97.4  107.6  -9.92             0            9.3                    27.5
# 23  100.9  107.5  -6.32             0            9.0                    25.8
# 24  105.1  104.3   0.98             0           10.5                    28.5
# 25  106.6  109.1  -2.32             0            8.0                    22.4
# 26  103.5   92.9  10.28             0            7.0                    18.5
# 27  102.7   98.2   4.08             0            8.6                    23.4
# 28   97.7   95.9   1.84             0            8.5                    23.9
# 29  104.1  104.6  -0.50             0            8.6                    24.2
# ..    ...    ...    ...           ...            ...                     ...
# 60  103.4  108.8  -5.00             0           11.2                    31.0
# 61  104.0  100.4   3.23             0           11.5                    30.4
# 62  106.6  110.3  -3.67             0           12.7                    35.7
# 63  108.2  108.0   0.07             0           10.0                    27.2
# 64  102.9  110.0  -6.84             0           11.0                    31.1
# 65  110.9  109.9   0.59             0           12.0                    32.1
# 66  102.3  105.4  -2.70             0           11.8                    32.8
# 67  110.0  108.5   1.57             0           11.5                    30.9
# 68  103.8  103.9  -0.26             0           10.8                    28.9
# 69  113.5  107.5   5.79             1           11.3                    28.9
# 70  112.4  103.9   8.21             0           15.3                    42.3
# 71  105.6  104.2   1.18             0            9.0                    24.5
# 72  109.0  109.0   0.15             0            9.5                    26.8
# 73  108.1  109.6  -1.44             0           10.0                    29.1
# 74   99.3  105.5  -5.81             0            9.2                    26.2
# 75  103.4  102.9   0.15             0           11.0                    30.6
# 76  106.5  106.8  -0.45             0            8.8                    24.7
# 77  109.5  107.3   2.35             0            8.0                    22.5
# 78  111.7  110.4   1.48             0           10.2                    28.2
# 79  104.5  108.0  -3.53             0            8.2                    23.3
# 80  107.9  104.4   3.42             0           10.7                    30.4
# 81  103.4  108.2  -4.92             0           10.3                    29.3
# 82  109.8  105.3   4.30             0           11.0                    29.8
# 83  103.9  113.3  -8.80             0            9.3                    27.9
# 84  105.6  103.0   2.60             0           10.3                    28.1
# 85   98.8  105.8  -6.60             0            9.0                    24.0
# 86  102.7   99.8   2.89             0            8.5                    24.1
# 87  111.7  103.9   7.29             0           11.8                    33.0
# 88  104.1   99.8   4.47             0           10.8                    29.6
# 89  106.6  106.0   0.53             0            9.9                    26.5
#
#     ThreePointPercentage
# 0                  0.350
# 1                  0.335
# 2                  0.352
# 3                  0.362
# 4                  0.371
# 5                  0.362
# 6                  0.344
# 7                  0.338
# 8                  0.345
# 9                  0.416
# 10                 0.347
# 11                 0.351
# 12                 0.364
# 13                 0.317
# 14                 0.331
# 15                 0.336
# 16                 0.345
# 17                 0.338
# 18                 0.360
# 19                 0.346
# 20                 0.349
# 21                 0.350
# 22                 0.339
# 23                 0.348
# 24                 0.370
# 25                 0.359
# 26                 0.375
# 27                 0.370
# 28                 0.355
# 29                 0.358
# ..                   ...
# 60                 0.360
# 61                 0.377
# 62                 0.356
# 63                 0.369
# 64                 0.355
# 65                 0.372
# 66                 0.360
# 67                 0.371
# 68                 0.373
# 69                 0.391
# 70                 0.362
# 71                 0.369
# 72                 0.354
# 73                 0.345
# 74                 0.352
# 75                 0.360
# 76                 0.355
# 77                 0.357
# 78                 0.362
# 79                 0.352
# 80                 0.354
# 81                 0.351
# 82                 0.369
# 83                 0.334
# 84                 0.366
# 85                 0.375
# 86                 0.352
# 87                 0.358
# 88                 0.366
# 89                 0.375
#
# [90 rows x 12 columns]>

# %%
# Look at the variable names 

variablenames = data.keys()
print (variablenames)
# Out:
# Index(['Team', 'Season', 'TeamSeason', 'Staff', 'Wins', 'PS/G', 'PA/G', 'SRS',
#        'Championship', 'ThreePointers', 'ThreePointersAttempted',
#        'ThreePointPercentage'],
#       dtype='object')

# %%
# check correlations

data.corr()
# Out:
#                            Staff      Wins      PS/G      PA/G       SRS  \
# Staff                   1.000000  0.144869  0.348020  0.215109  0.134047
# Wins                    0.144869  1.000000  0.579476 -0.510214  0.964361
# PS/G                    0.348020  0.579476  1.000000  0.365100  0.595375
# PA/G                    0.215109 -0.510214  0.365100  1.000000 -0.528911
# SRS                     0.134047  0.964361  0.595375 -0.528911  1.000000
# Championship           -0.032523  0.297613  0.284503 -0.070167  0.318012
# ThreePointers           0.399118  0.351308  0.598712  0.206758  0.365731
# ThreePointersAttempted  0.440198  0.226759  0.524711  0.268464  0.244760
# ThreePointPercentage    0.000120  0.575530  0.473681 -0.160034  0.569864
#
#                         Championship  ThreePointers  ThreePointersAttempted  \
# Staff                      -0.032523       0.399118                0.440198
# Wins                        0.297613       0.351308                0.226759
# PS/G                        0.284503       0.598712                0.524711
# PA/G                       -0.070167       0.206758                0.268464
# SRS                         0.318012       0.365731                0.244760
# Championship                1.000000       0.185927                0.130867
# ThreePointers               0.185927       1.000000                0.971180
# ThreePointersAttempted      0.130867       0.971180                1.000000
# ThreePointPercentage        0.246574       0.479599                0.260496
#
#                         ThreePointPercentage
# Staff                               0.000120
# Wins                                0.575530
# PS/G                                0.473681
# PA/G                               -0.160034
# SRS                                 0.569864
# Championship                        0.246574
# ThreePointers                       0.479599
# ThreePointersAttempted              0.260496
# ThreePointPercentage                1.000000

# %%
# Regular regression to predict championships based on size of analytics staff

model = smf.ols("Championship ~ Staff", data= data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Championship   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                   0.09318
# Date:                Fri, 28 Sep 2018   Prob (F-statistic):              0.761
# Time:                        08:20:37   Log-Likelihood:                 26.923
# No. Observations:                  90   AIC:                            -49.85
# Df Residuals:                      88   BIC:                            -44.85
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0420      0.034      1.225      0.224      -0.026       0.110
# Staff         -0.0046      0.015     -0.305      0.761      -0.035       0.025
# ==============================================================================
# Omnibus:                      129.462   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2743.458
# Skew:                           5.191   Prob(JB):                         0.00
# Kurtosis:                      27.976   Cond. No.                         4.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Regular regression to predict regular season wins based on size of analytics staff

model = smf.ols("Wins ~ Staff", data= data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   Wins   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.886
# Date:                Fri, 28 Sep 2018   Prob (F-statistic):              0.173
# Time:                        08:20:58   Log-Likelihood:                -352.40
# No. Observations:                  90   AIC:                             708.8
# Df Residuals:                      88   BIC:                             713.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     38.3535      2.321     16.523      0.000      33.741      42.966
# Staff          1.4011      1.020      1.373      0.173      -0.626       3.428
# ==============================================================================
# Omnibus:                        0.040   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.980   Jarque-Bera (JB):                0.096
# Skew:                          -0.047   Prob(JB):                        0.953
# Kurtosis:                       2.870   Cond. No.                         4.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Regular regression to predict SRS based on size of analytics staff

model = smf.ols("SRS ~ Staff", data= data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SRS   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.610
# Date:                Fri, 28 Sep 2018   Prob (F-statistic):              0.208
# Time:                        08:21:22   Log-Likelihood:                -260.15
# No. Observations:                  90   AIC:                             524.3
# Df Residuals:                      88   BIC:                             529.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.8760      0.833     -1.052      0.296      -2.531       0.779
# Staff          0.4644      0.366      1.269      0.208      -0.263       1.192
# ==============================================================================
# Omnibus:                        0.324   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.851   Jarque-Bera (JB):                0.120
# Skew:                           0.085   Prob(JB):                        0.942
# Kurtosis:                       3.053   Cond. No.                         4.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Regular regression to predict 3PA based on size of analytics staff

model = smf.ols("ThreePointersAttempted ~ Staff", data= data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     ThreePointersAttempted   R-squared:                       0.194
# Model:                                OLS   Adj. R-squared:                  0.185
# Method:                     Least Squares   F-statistic:                     21.15
# Date:                    Fri, 28 Sep 2018   Prob (F-statistic):           1.41e-05
# Time:                            08:21:43   Log-Likelihood:                -254.34
# No. Observations:                      90   AIC:                             512.7
# Df Residuals:                          88   BIC:                             517.7
# Df Model:                               1
# Covariance Type:                nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     23.7137      0.781     30.371      0.000      22.162      25.265
# Staff          1.5781      0.343      4.599      0.000       0.896       2.260
# ==============================================================================
# Omnibus:                        0.142   Durbin-Watson:                   1.698
# Prob(Omnibus):                  0.931   Jarque-Bera (JB):                0.329
# Skew:                           0.001   Prob(JB):                        0.848
# Kurtosis:                       2.704   Cond. No.                         4.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Regular regression to predict 3P% based on size of analytics staff

model = smf.ols("ThreePointPercentage ~ Staff", data= data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     ThreePointPercentage   R-squared:                       0.000
# Model:                              OLS   Adj. R-squared:                 -0.011
# Method:                   Least Squares   F-statistic:                 1.278e-06
# Date:                  Fri, 28 Sep 2018   Prob (F-statistic):              0.999
# Time:                          08:22:09   Log-Likelihood:                 243.62
# No. Observations:                    90   AIC:                            -483.2
# Df Residuals:                        88   BIC:                            -478.2
# Df Model:                             1
# Covariance Type:              nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3572      0.003    115.700      0.000       0.351       0.363
# Staff       1.534e-06      0.001      0.001      0.999      -0.003       0.003
# ==============================================================================
# Omnibus:                        5.318   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                5.258
# Skew:                           0.359   Prob(JB):                       0.0721
# Kurtosis:                       3.942   Cond. No.                         4.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Regular regression to predict 3P% based on size of analytics staff

model = smf.ols("ThreePointers ~ Staff", data= data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          ThreePointers   R-squared:                       0.159
# Model:                            OLS   Adj. R-squared:                  0.150
# Method:                 Least Squares   F-statistic:                     16.67
# Date:                Fri, 28 Sep 2018   Prob (F-statistic):           9.75e-05
# Time:                        08:22:33   Log-Likelihood:                -171.96
# No. Observations:                  90   AIC:                             347.9
# Df Residuals:                      88   BIC:                             352.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      8.4882      0.313     27.154      0.000       7.867       9.109
# Staff          0.5610      0.137      4.083      0.000       0.288       0.834
# ==============================================================================
# Omnibus:                        0.328   Durbin-Watson:                   1.596
# Prob(Omnibus):                  0.849   Jarque-Bera (JB):                0.496
# Skew:                           0.097   Prob(JB):                        0.780
# Kurtosis:                       2.692   Cond. No.                         4.65
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
